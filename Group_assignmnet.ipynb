# %% [markdown]
# <a href="https://colab.research.google.com/github/jimkella/Anypic/blob/master/Group_assignmnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd



df_peugot_1 = pd.read_csv("peugeot_207_01.csv", delimiter=';', decimal=',')
df_peugot_2 = pd.read_csv("peugeot_207_02.csv", delimiter=';', decimal=',')

df_corsa_1 = pd.read_csv("opel_corsa_01.csv", delimiter=';', decimal=',')
df_corsa_2 = pd.read_csv("opel_corsa_02.csv", delimiter=';', decimal=',')
# Out:
#      AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 0                  NaN                         0                 NaN
# 1                  NaN                         0                 NaN
# 2                  NaN                         0                 NaN
# 3                  NaN                         0                 NaN
# 4                  NaN                         0                 NaN
# ...                ...                       ...                 ...
# 8609              -0,5                         0         26,11499948
# 8610                 0                         0         25,39499953
# 8611      -0,099998474                         0         24,73499955
# 8612               0,5                         0         24,07499958
# 8613       0,800003052                         0         23,50499957
#
#      VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# ...

# %% [markdown]
# # New section
